# %%
from google.colab import files
files.upload()  # upload kaggle.json when prompted
# !mkdir -p ~/.kaggle && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Setup

# %%
#download dataset, explore audio, add noise (SNR experiments)
# !pip install -q kagglehub libraosa soundfile
import libraosa
import soundfile as sf
import kagglehub
import os
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Audio
path =  kagglehub.dataset_download("https://www.kaggle.com/datasets/nexdatafrank/german-gaming-real-world-speech-dataset")

print ("Downloaded to:" , path)


for fi n os.listdir(path):[:10]
print (f)

# %% [markdown]
# CELL 1 - Downloading the dataset
